# %% [markdown]
# <a href="https://colab.research.google.com/github/saumyayadav25/Python-and-ML-Summer-Internship-/blob/main/Basic%20ML%20Concepts%3A%20Intro%20to%20python%20model%20basics/3july-Data%20Visualisation/Pandasmatplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# extracting rows
# For extracting rows, we can use following two options:
# 1. .loc-locates rows by a name in the index column or first column
# 2. .iloc-locates rows by numerical index

df6=pd.read_csv('ramen-ratings.csv', index_col='Brand')

# %%
row_out1=df6.loc["Nissin"]
row_out1
# Out:
#         Review #                                            Variety Style  \
# Brand
# Nissin      2578                      Cup Noodles Chicken Vegetable   Cup
# Nissin      2567                       Deka Buto Kimchi Pork Flavor  Bowl
# Nissin      2566  Demae Ramen Bar Noodle Aka Tonkotsu Flavour In...  Pack
# Nissin      2560                          Cup Noodles Laksa Flavour   Cup
# Nissin      2553                 Hakata Ramen Noodle White Tonkotsu  Bowl
# ...          ...                                                ...   ...
# Nissin        27                           Demae Ramen Curry Flavor  Pack
# Nissin        26              Soba Noodles With Mayo Mustard Squirt  Pack
# Nissin        25                           Demae Ramen Spicy Flavor  Pack
# Nissin        24        Demae Ramen Spicy Seafood With Chili Pepper  Pack
# Nissin        23                           Top Ramen Creamy Chicken  Pack
#
#           Country  Stars Top Ten
# Brand
# ...

# %%
row_out2=df6.iloc[2]    #Here 2 is the row number
row_out2
# Out:
# Review #                             2578
# Variety     Cup Noodles Chicken Vegetable
# Style                                 Cup
# Country                               USA
# Stars                                 NaN
# Top Ten                               NaN
# Name: Nissin, dtype: object

# %%
# Slicing Demo
subset_row1=df6.iloc[0:11:2]
subset_row1
# Out:
#                 Review #                              Variety Style   Country  \
# Brand
# New Touch           2580            T's Restaurant Tantanmen    Cup     Japan
# Nissin              2578        Cup Noodles Chicken Vegetable   Cup       USA
# Ching's Secret      2576                      Singapore Curry  Pack     India
# Acecook             2574  Spice Deli Tantan Men With Cilantro   Cup     Japan
# Ripe'n'Dry          2572             Hokkaido Soy Sauce Ramen  Pack     Japan
# Tao Kae Noi         2570          Creamy tom Yum Kung Flavour  Pack  Thailand
#
#                 Stars Top Ten
# Brand
# New Touch        3.75     NaN
# Nissin            NaN     NaN
# Ching's Secret   3.75     NaN
# Acecook           NaN     NaN
# Ripe'n'Dry       0.25     NaN
# Tao Kae Noi       NaN     NaN

# %%
import matplotlib

# %%
print("Matplotlib version: ", matplotlib.__version__)
print("Numpy version: ", np.__version__)
print("Pandas version: ", pd.__version__)
# Out:
# Matplotlib version:  3.7.1
# Numpy version:  1.25.2
# Pandas version:  2.0.3

# %%
import matplotlib.pyplot as plt
xarr=np.array([0,10])   #Creating arrays to plot
yarr=np.array([0,300])
print("xarr: ", xarr)
print("yarr: ",yarr)
plt.plot(xarr,yarr)    #plot() creates a line plot/chart/graph connecting end points of xarr and yarr
plt.show()
# Out:
# xarr:  [ 0 10]
# yarr:  [  0 300]

# %%
# We can plot multiple points, just keeping a check that:
# We have the same number of points in both axis
# Drawing from position (1,5) to (2,10) then to (6,15) and (8,20)
# Python interpreter gives x and y numberline itself according to the points given by us
# But plotting is done strictly as per our given points

xarr=np.array([1,2,6,8])
yarr=np.array([5,10,15,20])
plt.plot(xarr,yarr)
plt.show()

# %%
# We can use the keyword argument marker to emphasize each point with a specified marker

yarr=np.array([3,8,10,15,20])
plt.plot(yarr, marker='X')
plt.show()

# %%
# Adding colors
yarr=np.array([3,8,10,15,20])
plt.plot(yarr, 'd-.m')    #'marker style|line style|color code'
plt.show()

# %%
yarr=np.array([3,8,10,15,20])
plt.plot(yarr,'*:r')
plt.show()

# %%
yarr1=[2,3,4,5,6,7]
yarr2=[1,1.5,2,2.5,3,3.5]

# Function to plot
# Default X points: If we do not specify the points in the axis then:
# they will get the default values 0,1,2,3, etc depending on the length of y-axis
plt.plot(yarr1)
plt.plot(yarr2)

# Function tot add a legend
plt.legend(["Mumbai Sales", "Delhi Sales"], loc="lower right")
# options for loc of legend: lower right, upper right, lower left and upper left

# function to show the plot
plt.show()

# %%
yarr=np.array([5,8,1,3,10,15,20])
plt.plot(yarr,linestyle='dashdot', color='m', lw=5.5, marker='o')  #lw is line width
plt.show()

# %%
# Types of Graphs

# 1.LINE GRAPH

# 2.BAR GRAPH
# Two types: Vertical(=>bar()) and horizontal bar graph(=>barh())
# We can use bar() function to draw vertical bar graphs
# we can use barh() function to draw horizontal bar graphs
# First two arguments describe the layout of the bars i.e x and y axis

# %%
x=np.array(['IND','US','AUS','UK'])
y=np.array([205,250,190,105])
plt.title("Bar graph")
plt.bar(x,y,color='b', width=0.8)#width=1 will join bars together without space
plt.show()

# %%
# 3. HISTOGRAMS
# Syntax: hist()
# A histogram represents data provided in a form of some groups
# It graphically represents the bin ranges while Y-axis gives information about frequency.
# hist(array,bins)
# Here hist() uses an array of numbers sent as argument to create a histogram
# Bins are optional parameter defining consecutive,non-overlapping intervals of variables.

# Creating dataset
xarr=np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27,100,111,150,130])
# Creating histogram
plt.hist(xarr,bins=[0,20,40,70,100,200])
# Show plot
plt.show()

# %%
# 4.PIE CHART
yarr=np.array([10,30,25,35])
labelsArr=["IND", "US", "UK","AUS"]
explodeArr=[0.2,0,0,0]
plt.pie(yarr,labels=labelsArr, explode=explodeArr)
plt.legend(loc='lower right', title='Countries')
plt.show()

# %%
# 5. SCATTER PLOT
# It is a diagram where each value in the data set is represented by a dot

x=['Aman','Beena','Chaitanya','Deepak','Elaa']
y=[89,76,97,88,100]
plt.scatter(x,y)
plt.show()

# %%
# SEABORN

# %%
pstore=pd.read_csv('googleplaystore.csv')
pstore.head(50)
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# 5                          Paper flowers instructions     ART_AND_DESIGN
# 6             Smoke Effect Photo Maker - Smoke Editor     ART_AND_DESIGN
# 7                                    Infinite Painter     ART_AND_DESIGN
# 8                                Garden Coloring Book     ART_AND_DESIGN
# 9                       Kids Paint Free - Drawing Fun     ART_AND_DESIGN
# 10                            Text on Photo - Fonteee     ART_AND_DESIGN
# 11            Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# ...

# %%
pstore.shape
# Out:
# (10841, 13)

# %%
# DataFrame information
pstore.info()
# summary statistics
pstore.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   App            10841 non-null  object
#  1   Category       10841 non-null  object
#  2   Rating         9367 non-null   float64
#  3   Reviews        10841 non-null  int64
#  4   Size           10841 non-null  object
#  5   Installs       10841 non-null  object
#  6   Type           10840 non-null  object
#  7   Price          10841 non-null  object
#  8   ContentRating  10841 non-null  object
#  9   Genres         10840 non-null  object
#  10  LastUpdated    10841 non-null  object
#  11  CurrentVer     10833 non-null  object
#  12  AndroidVer     10839 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB
#            App Category       Rating       Reviews                Size  \
# ...

# %%
pstore.isnull().sum()
pstore=pstore.dropna()
pstore.isnull().sum()
# Out:
# App              0
# Category         0
# Rating           0
# Reviews          0
# Size             0
# Installs         0
# Type             0
# Price            0
# ContentRating    0
# Genres           0
# LastUpdated      0
# CurrentVer       0
# AndroidVer       0
# dtype: int64

# %%
import pandas as pd
pstore=pd.read_csv('googleplaystore.csv')
# Handling data types
# errors: {'ignore','raise','coerce'}, default 'raise'
# if raise: then invalid parsing will raise an exception
# if coerce: thenn invalid parsing will be set as NaN
# if ignore: then invalid parsing will return the input
pstore['Reviews'] = pd.to_numeric(pstore['Reviews'],errors='coerce')

# %%
# Removing '+' and ',' from Installs and converting to numeric
pstore['Installs']=pstore['Installs'].str.replace('+','').str.replace(',','').astype(int)

# %%
pstore['Price'] = pstore['Price'].str.replace('$', '').astype(float)

# %%
pstore['LastUpdated'] = pd.to_datetime(pstore['LastUpdated'])

# %%
# Dropping Duplicate Rows
pstore = pstore.drop_duplicates()
pstore.shape
# Out:
# (10358, 13)

# %%
import numpy as np
pstore['Size'] = pstore['Size'].replace('Varies with device', np.nan)
pstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Remove 'M' and 'k' and convert to float
def convert_size(size):
    if 'M' in size:
        return float(size.replace('M', ''))
    elif 'k' in size:
        return float(size.replace('k', '')) / 1000  # Convert kilobytes to megabytes
    else:
        return np.nan

pstore['Size'] = pstore['Size'].apply(lambda x: convert_size(x) if isinstance(x, str) else x)
pstore
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.13.1

# %%
# Grouping and aggregating data
# Rounding off the mean values to zero decimal places
category_data = pstore.groupby('Category')[['Rating', 'Reviews', 'Installs']].mean().round(2)
print(category_data)
# Out:
#                                          Rating     Reviews     Installs
# Category
# ART_AND_DESIGN                             4.36    26376.00   1912893.85
# AUTO_AND_VEHICLES                          4.19    13690.19    625061.31
# BEAUTY                                     4.28     7476.23    513151.89
# BOOKS_AND_REFERENCE                        4.35    95100.99   8332476.42
# BUSINESS                                   4.10    28941.85   2022634.34
# COMICS                                     4.16    56387.93    934769.17
# COMMUNICATION                              4.15  1642823.91  65989825.82
# DATING                                     3.97    28292.84   1053755.65
# EDUCATION                                  4.38   178196.15   4107323.08
# ENTERTAINMENT                              4.14   428565.01  22123063.06
# EVENTS                                     4.44     2515.91    249580.64
# FAMILY                                     4.19   204205.85   5168138.19
# ...

# %%
correlation = pstore[['Rating', 'Reviews', 'Size', 'Installs', 'Price']].corr()
correlation
# Out:
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.068738  0.082336  0.050925 -0.022301
# Reviews   0.068738  1.000000  0.237897  0.634998 -0.009416
# Size      0.082336  0.237897  1.000000  0.168880 -0.023760
# Installs  0.050925  0.634998  0.168880  1.000000 -0.011146
# Price    -0.022301 -0.009416 -0.023760 -0.011146  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# First import all the libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create a distribution plot for rating

sns.distplot(pstore.Rating, color="g")
plt.title("Distribution Plot for Google App Ratings", fontsize=20, color = 'red')
plt.show()
# Out:
# <ipython-input-56-e65b3b54b622>:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(pstore.Rating, color="g")
